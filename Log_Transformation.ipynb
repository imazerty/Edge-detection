# %% [markdown]
# <a href="https://colab.research.google.com/github/imazerty/Edge-detection/blob/master/Log_Transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # log transform sur la neg_image (255 - img)

# %%
# %matplotlib inline
import imageio
import numpy as np
import matplotlib.pyplot as plt

gray = lambda rgb : np.dot(rgb[... , :3] , [0.299 , 0.587, 0.114]) 

pic = imageio.imread('yft_neg.jpg')
gray1 = gray(pic)


'''
log transform
-> s = c*log(1+r)
So, we calculate constant c to estimate s
-> c = (L-1)/log(1+|I_max|)
'''
max_ = np.max(gray1)

def log_transform(gray1, max_):
    return (255/np.log(1+max_)) * np.log(1+gray1)
plt.figure(figsize = (5,5))
plt.imshow(log_transform(gray1, max_), cmap = plt.get_cmap(name = 'gray'))
plt.axis('off');

# %% [markdown]
# # log transform sur img (retenue)

# %%
import matplotlib.pyplot as plt


#x1 = np.linspace(0.0, 5.0)
#x2 = np.linspace(0.0, 2.0)

#y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
#y2 = np.cos(2 * np.pi * x2)
"""
plt.subplot(2, 1, 1)
plt.imshow(log_transform(gray1, max_))
plt.title('A tale of 2 subplots')
plt.ylabel('log(neg_img)')

plt.subplot(2, 1, 2)

plt.plot(log_transform(gray2, max_2))
plt.xlabel('time (s)')
plt.ylabel('log(img)')
plt.show()
"""
pic2 = imageio.imread('Yellowfin Tuna.jpg')
gray2 = gray(pic2)
max_2 = np.max(gray2)

plt.figure()
plt.imshow(log_transform(gray2, max_2))

plt.ylabel('log(img)')
plt.show()
plt.imsave('log(img).jpg', log_transform(gray2, max_2))

# %% [markdown]
# # Encore plus de log transform par curiosité:

# %%
gray3 = gray(pic3)
pic3 = imageio.imread('log(img).jpg')
max_3 = np.max(gray3)
pic4 = log_transform(gray3, max_3)
plt.figure()
plt.imshow(pic4)

plt.ylabel('log(log(img))')
plt.show()
plt.imsave('log(log(img)).jpg', pic4)

# %%
max_4 = np.max(gray4)
pic4 = imageio.imread('log(log(img)).jpg')

gray4 = gray(pic4)
pic5 = log_transform(gray4, max_4)

plt.figure()
plt.imshow(pic5)

plt.ylabel('log(log(img))')
plt.show()
plt.imsave("log(log(log(img)))",pic5)
